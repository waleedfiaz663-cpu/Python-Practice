# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/ArrayProperties.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.arange(1,10).reshape(3,3)

print("Shape is : ",arr.shape)

print("")

print("Dimension is : ",arr.ndim)

print("")

print("Size is : ",arr.size)

print("")

print("Data Type is : ",arr.dtype)

print("")
# Out:
# Shape is :  (3, 3)
#
# Dimension is :  2
#
# Size is :  9
#
# Data Type is :  int64
