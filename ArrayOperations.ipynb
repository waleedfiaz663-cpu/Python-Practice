# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/ArrayOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([2,4,6,8])

B = np.array([1,3,5,7])

print("Addition is : ",A+B)

print("")

print("Subtraction is : ",A-B)

print("")

print("Multiplication is : ",A*B)

print("")

print("Division is : ",A/B)
# Out:
# Addition is :  [ 3  7 11 15]
#
# Subtraction is :  [1 1 1 1]
#
# Multiplication is :  [ 2 12 30 56]
#
# Division is :  [2.         1.33333333 1.2        1.14285714]
