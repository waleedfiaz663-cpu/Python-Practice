# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/Nbr%2CFloattype%2CDataType.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=input(" Enter First Number ")
num2=input(" Enter Second Number ")

num1=float(num1)
num2=float(num2)

print(" Addition :",num1+num2)
print("Subtraction :",num1-num2)
print("Multiplication :",num1*num2)
print("Division :",num1/num2)

print(f"DataType of num1 is{type(num1)}")
print(f"DataType of num2 is{type(num2)}")
# Out:
#  Enter First Number 6
#  Enter Second Number 4
#  Addition : 10.0
# Subtraction : 2.0
# Multiplication : 24.0
# Division : 1.5
# DataType of num1 is<class 'float'>
# DataType of num2 is<class 'float'>
