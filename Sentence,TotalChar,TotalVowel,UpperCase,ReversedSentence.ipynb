# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/Sentence%2CTotalChar%2CTotalVowel%2CUpperCase%2CReversedSentence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence=input("Enter a Sentence :")

total_char=len(sentence)
print("total char :",total_char)

total_vowels=sum(1 for ch in sentence if ch in"aeiouAEIOU")
print("total vowels :",total_vowels)

upper_case=sentence.upper()
print("upper case :",upper_case)

reversed_sentence=sentence[::-1]
print("reversed sentence :",reversed_sentence)
# Out:
# Enter a Sentence :Me Waleed Student Of Computer Science
# total char : 37
# total vowels : 13
# upper case : ME WALEED STUDENT OF COMPUTER SCIENCE
# reversed sentence : ecneicS retupmoC fO tnedutS deelaW eM
