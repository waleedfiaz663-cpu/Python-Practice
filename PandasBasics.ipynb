# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/PandasBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

Data = {
    "Name":["Ali","Sara","John","Ayesha"],
    "Age":[20,21,19,22],
    "Marks":[85,90,78,88]
}

df=pd.DataFrame(Data)

print("DataFrame : ")

print("")

print(df)

print("")

print("Summary : ")

print("")

print(df.describe(include='all'))
# Out:
# DataFrame :
#
#      Name  Age  Marks
# 0     Ali   20     85
# 1    Sara   21     90
# 2    John   19     78
# 3  Ayesha   22     88
#
# Summary :
#
#        Name        Age      Marks
# count     4   4.000000   4.000000
# unique    4        NaN        NaN
# top     Ali        NaN        NaN
# freq      1        NaN        NaN
# mean    NaN  20.500000  85.250000
# std     NaN   1.290994   5.251984
# min     NaN  19.000000  78.000000
# 25%     NaN  19.750000  83.250000
# 50%     NaN  20.500000  86.500000
# 75%     NaN  21.250000  88.500000
# max     NaN  22.000000  90.000000
