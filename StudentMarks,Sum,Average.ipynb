# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/StudentMarks%2CSum%2CAverage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(" Please Enter Your Name ")
name=input()
print(" Please Enter Your Rollno ")
rollno=input()
print(" Enter Marks Of Subject 1 ")
marks1=int(input())
print(" Enter Marks  Of SUbject 2 ")
marks2=int(input())
print(" Enter Marks Of Subject 3 ")
marks3=int(input())
print("===================")
print("Name :",name)
print("RollNo : ",rollno)
totalmarks=marks1+marks2+marks3
print("Total marks :",totalmarks)
average=totalmarks/3
print("Average :",average)
print("===================")
# Out:
#  Please Enter Your Name
# waleed
#  Please Enter Your Rollno
# 135
#  Enter Marks Of Subject 1
# 77
#  Enter Marks  Of SUbject 2
# 88
#  Enter Marks Of Subject 3
# 99
# ...
# Name : waleed
# RollNo :  135
# Total marks : 264
# Average : 88.0
# ...
