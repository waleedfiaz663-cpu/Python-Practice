# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/TotalChar%2CVowels%2CUppercase%2CReversed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence=input(" Please Enter a Sentence ")


total_char=len(sentence)
print("total char : ",total_char)


total_vowels=sum(1 for char in sentence if char in"aeiouAEIOU")
print("tolat vowels :",total_vowels)


upper_case=sentence.upper()
print("upper case :",upper_case)


reversed_sentence=sentence[::-1]
print("reversed sentence :",reversed_sentence)
# Out:
#  Please Enter a Sentence my name is waleed student of computer science in comsats
# total char :  56
# tolat vowels : 18
# upper case : MY NAME IS WALEED STUDENT OF COMPUTER SCIENCE IN COMSATS
# reversed sentence : stasmoc ni ecneics retupmoc fo tneduts deelaw si eman ym
