# %% [markdown]
# <a href="https://colab.research.google.com/github/waleedfiaz663-cpu/Python-Practice/blob/main/Sets%2CUnion%2CIntersection%2CDifference%2CSymmetricDifference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1={1,2,3,4,5}

set2={4,5,6,7,8}

print("set 1 :",set1)

print("")

print("set 2 :",set2)

print("")

print("==========================================")

print("Union :",set1|set2)

print("")

print("Intersection :",set1&set2)

print("")

print("Difference :",set1-set2)

print("")

print("Symmetric Difference :",set1^set2)

print("")

print("==========================================")
# Out:
# set 1 : {1, 2, 3, 4, 5}
#
# set 2 : {4, 5, 6, 7, 8}
#
# ...
# Union : {1, 2, 3, 4, 5, 6, 7, 8}
#
# Intersection : {4, 5}
#
# Difference : {1, 2, 3}
#
# Symmetric Difference : {1, 2, 3, 6, 7, 8}
#
# ...
